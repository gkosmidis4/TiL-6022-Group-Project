# %%
# !pip install openrouteservice
import openrouteservice
import pandas as pd
# Out:
# Requirement already satisfied: openrouteservice in c:\users\julia\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: requests>=2.0 in c:\users\julia\anaconda3\lib\site-packages (from openrouteservice) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\julia\anaconda3\lib\site-packages (from requests>=2.0->openrouteservice) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\julia\anaconda3\lib\site-packages (from requests>=2.0->openrouteservice) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\julia\anaconda3\lib\site-packages (from requests>=2.0->openrouteservice) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\julia\anaconda3\lib\site-packages (from requests>=2.0->openrouteservice) (2025.8.3)

# %%
client = openrouteservice.Client(key='eyJvcmciOiI1YjNjZTM1OTc4NTExMTAwMDFjZjYyNDgiLCJpZCI6IjFjZjA4YjdmNzE4NzRiOWM4OGQxN2EzMGZhZmYxNWFiIiwiaCI6Im11cm11cjY0In0=')

csv_file = "../base data/Dutch_Central_Stations_Coordinates.csv"
df = pd.read_csv(csv_file)
stations = df['Station Name'].tolist()
coords = list(zip(df['Longitude'], df['Latitude']))

matrix = client.distance_matrix(
    locations=coords,
    profile='driving-car',
    metrics=['distance', 'duration'],
    units='km'
)

distance_matrix = pd.DataFrame(matrix['distances'], index=stations, columns=stations)
duration_matrix = pd.DataFrame(matrix['durations'], index=stations, columns=stations)
distance_matrix.to_csv("../processed_data/CarDistance_matrix.csv")
duration_matrix.to_csv("../processed_data/CarTime_matrix.csv")

print("Distance Matrix (km):")
print(distance_matrix)
print("\nDuration Matrix (seconds):")
print(duration_matrix)
# Out:
# Distance Matrix (km):
#                      Amsterdam Centraal  Rotterdam Centraal  \
# Amsterdam Centraal                 0.00               82.52
# Rotterdam Centraal                77.42                0.00
# Den Haag Centraal                 62.62               24.51
# Utrecht Centraal                  46.34               56.20
# Eindhoven Centraal               129.68              112.18
# Tilburg Centraal                 122.82               80.28
# Almere Centrum                    34.57               96.99
# Groningen Centraal               181.69              246.26
# Breda Centraal                   111.92               50.35
# Nijmegen Centraal                123.60              117.42
# Leeuwarden Centraal              138.26              205.63
# Maastricht Centraal              217.54              218.80
# TU Delft Campus                   68.13               12.40
#
#                      Den Haag Centraal  Utrecht Centraal  Eindhoven Centraal  \
# Amsterdam Centraal               67.51             46.62              130.86
# Rotterdam Centraal               21.95             56.78              114.28
# Den Haag Centraal                 0.00             61.27              140.35
# Utrecht Centraal                 60.81              0.00               91.69
# Eindhoven Centraal              135.64             89.81                0.00
# Tilburg Centraal                103.74             82.95               42.15
# Almere Centrum                   87.17             41.69              125.90
# Groningen Centraal              234.29            190.96              254.38
# Breda Centraal                   73.81             72.05               62.55
# Nijmegen Centraal               140.88             89.45               71.40
# Leeuwarden Centraal             190.62            161.45              242.25
# Maastricht Centraal             242.26            177.67               86.75
# TU Delft Campus                  12.66             65.33              128.24
#
#                      Tilburg Centraal  Almere Centrum  Groningen Centraal  \
# Amsterdam Centraal             121.36           33.62              181.46
# Rotterdam Centraal              82.13           97.73              246.37
# Den Haag Centraal              108.19           86.15              233.99
# Utrecht Centraal                82.18           40.44              189.08
# Eindhoven Centraal              34.33          124.05              251.99
# Tilburg Centraal                 0.00          117.01              265.65
# Almere Centrum                 116.31            0.00              155.78
# Groningen Centraal             254.29          155.70                0.00
# Breda Centraal                  30.40          106.10              254.74
# Nijmegen Centraal               71.31          109.10              188.43
# Leeuwarden Centraal            236.07          126.19               65.03
# Maastricht Centraal            121.59          211.91              399.42
# TU Delft Campus                 96.09           91.66              239.50
#
#                      Breda Centraal  Nijmegen Centraal  Leeuwarden Centraal  \
# Amsterdam Centraal           111.30             122.02               137.25
# Rotterdam Centraal            50.17             117.41               204.98
# Den Haag Centraal             76.24             140.31               190.18
# Utrecht Centraal              72.13              90.06               160.93
# Eindhoven Centraal            60.58              65.06               239.14
# Tilburg Centraal              28.67              69.14               237.49
# Almere Centrum               106.26             108.73               127.63
# Groningen Centraal           255.53             206.92                64.53
# Breda Centraal                 0.00              94.84               226.59
# Nijmegen Centraal             99.80               0.00               175.58
# Leeuwarden Centraal          226.02             194.79                 0.00
# Maastricht Centraal          147.84             138.70               321.60
# TU Delft Campus               64.13             131.37               195.69
#
#                      Maastricht Centraal  TU Delft Campus
# Amsterdam Centraal                217.32            72.84
# Rotterdam Centraal                219.45            12.69
# Den Haag Centraal                 245.52            14.83
# Utrecht Centraal                  178.15            66.01
# Eindhoven Centraal                 87.95           126.38
# Tilburg Centraal                  127.82            94.47
# Almere Centrum                    212.36            92.51
# Groningen Centraal                397.92           239.63
# Breda Centraal                    148.22            64.54
# Nijmegen Centraal                 139.89           131.62
# Leeuwarden Centraal               323.55           195.95
# Maastricht Centraal                 0.00           232.99
# TU Delft Campus                   233.41             0.00
#
# Duration Matrix (seconds):
#                      Amsterdam Centraal  Rotterdam Centraal  \
# Amsterdam Centraal                 0.00             4050.03
# Rotterdam Centraal              4105.97                0.00
# Den Haag Centraal               3281.09             1553.31
# Utrecht Centraal                2543.26             2999.04
# Eindhoven Centraal              6054.75             5538.57
# Tilburg Centraal                5740.73             4072.27
# Almere Centrum                  2067.51             4644.47
# Groningen Centraal              8030.14            10646.29
# Breda Centraal                  5397.00             3009.67
# Nijmegen Centraal               5930.40             5735.32
# Leeuwarden Centraal             6433.21             9144.57
# Maastricht Centraal             9406.82             8740.14
# TU Delft Campus                 3532.92             1066.93
#
#                      Den Haag Centraal  Utrecht Centraal  Eindhoven Centraal  \
# Amsterdam Centraal             3411.81           2650.71             6353.00
# Rotterdam Centraal             1640.87           3028.40             5914.10
# Den Haag Centraal                 0.00           3009.50             6548.53
# Utrecht Centraal               3089.05              0.00             4694.09
# Eindhoven Centraal             6268.44           4427.29                0.00
# Tilburg Centraal               4802.14           4113.28             2769.91
# Almere Centrum                 4177.12           2459.81             6076.23
# Groningen Centraal            10139.75           8461.63            11311.15
# Breda Centraal                 3739.54           3769.54             3712.63
# Nijmegen Centraal              6465.19           4420.85             4028.53
# Leeuwarden Centraal            8506.36           7461.29            11001.36
# Maastricht Centraal            9470.01           7779.36             4266.01
# TU Delft Campus                1067.82           3172.85             6062.15
#
#                      Tilburg Centraal  Almere Centrum  Groningen Centraal  \
# Amsterdam Centraal            5734.43         1971.07             8165.00
# Rotterdam Centraal            4257.45         4582.65            10752.52
# Den Haag Centraal             4891.89         3900.56            10094.50
# Utrecht Centraal              4075.52         2498.39             8668.26
# Eindhoven Centraal            2133.47         5743.26            11047.31
# Tilburg Centraal                 0.00         5421.80            11591.67
# Almere Centrum                5454.19            0.00             7036.30
# Groningen Centraal           11311.46         6876.56                0.00
# Breda Centraal                2055.98         5078.06            11247.93
# Nijmegen Centraal             4028.84         5264.26             9238.09
# Leeuwarden Centraal          10455.67         5876.22             3743.44
# Maastricht Centraal           5447.86         9095.33            13156.62
# TU Delft Campus               4405.50         4152.39            10346.33
#
#                      Breda Centraal  Nijmegen Centraal  Leeuwarden Centraal  \
# Amsterdam Centraal          5255.44            5745.15              6559.56
# Rotterdam Centraal          3045.46            5721.76              9150.64
# Den Haag Centraal           3679.89            6220.39              8325.76
# Utrecht Centraal            3596.53            4362.93              7594.69
# Eindhoven Centraal          3317.95            3563.26             10623.09
# Tilburg Centraal            1851.65            4232.74             10518.10
# Almere Centrum              4975.20            5172.48              5962.73
# Groningen Centraal         10977.02            9171.12              3609.96
# Breda Centraal                 0.00            4874.26             10174.36
# Nijmegen Centraal           4931.44               0.00              8813.87
# Leeuwarden Centraal         9976.68            8861.33                 0.00
# Maastricht Centraal         6632.34            6303.15             13815.47
# TU Delft Campus             3193.51            5869.81              8577.59
#
#                      Maastricht Centraal  TU Delft Campus
# Amsterdam Centraal               9475.48          3428.58
# Rotterdam Centraal               8917.70          1119.72
# Den Haag Centraal                9552.13           931.86
# Utrecht Centraal                 7816.57          3119.69
# Eindhoven Centraal               4527.86          5747.29
# Tilburg Centraal                 5818.54          4280.99
# Almere Centrum                   9198.71          4193.88
# Groningen Centraal              13321.27         10156.51
# Breda Centraal                   6761.26          3218.39
# Nijmegen Centraal                6539.69          5944.03
# Leeuwarden Centraal             13944.51          8523.12
# Maastricht Centraal                 0.00          8948.85
# TU Delft Campus                  9065.75             0.00
